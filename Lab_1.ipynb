# %% [markdown]
# <a href="https://colab.research.google.com/github/Pandabigman/ShortPyProjects/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Example of print:**

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# **2. Example of calculating**

# %%
a = float(1)
b = float(2)
print(a+b)
# Out:
# 3.0

# %% [markdown]
# **3. Example of import and show image**

# %%
from PIL import Image

img = Image.open('/content/Lab_1_lena_image.jpg')   #read image

display(img)   #display the read image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# **4. Using Numpy library for matrix operations**

# %%
import numpy as np

# %% [markdown]
# Create matrix A = [1, 2; 3, 4]

# %%
A = np.array([[1,2],[3,4]])
print (A)
# Out:
# [[1 2]
#  [3 4]]

# %%
############# Create matrix B = [6,7;8,9] here #############

B =  np.array([[6,7],[8,9]]) ###### Your code Here #############
print (B)
# Out:
# [[6 7]
#  [8 9]]

# %%
############ Find matrix BT, which is the transpose of matrix B ######

 ###### Your code Here   #############
 #or np.transpose(B)
BT = B.T
print (BT)
# Out:
# [[6 8]
#  [7 9]]

# %%
############# Calculating the matrix C, which is the sum of A and B here ################

C = A + B ###### Your code Here #############
print (C)
# Out:
# [[ 7  9]
#  [11 13]]

# %%
########### Calculating the matrix E, which is the matrix multiplication between A and B #############

E = A @ B ###### Your code Here  or np.dot() #############
print (A)
print(B)
print (E)
# Out:
# [[1 2]
#  [3 4]]
# [[6 7]
#  [8 9]]
# [[22 25]
#  [50 57]]

# %%
########## Calculating the Matrix F, which is the elementwise multiplication between A and B ###########

F = A*B###### Your code Here #############
print (F)

# %%
############ Calculating the matrix D, which is the B subtracting A here ##################
D = B - A

print (D)
# Out:
# [[5 5]
#  [5 5]]
